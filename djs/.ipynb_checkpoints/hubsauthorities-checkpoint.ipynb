null, 0.45933450141908283, 0.2952614385647552, null, 0.3035817393409761, 0.30526772582258266, null, 0.3035817393409761, 0.3164992546011584, null, 0.5255372899144904, 0.3934180915241442, null, 0.40039545650724995, 0.4004971444173481, null, 0.40039545650724995, 0.412540196271388, null, 0.5255372899144904, 0.3063042576216754, null, 0.31529265521747885, 0.32855462202432684, null, 0.31529265521747885, 0.31780681038945974, null, 0.5255372899144904, 0.9588175952258098, null, 0.9449275502950986, 0.9309763155609665, null, 0.9449275502950986, 0.9344994625990988, null, 0.5255372899144904, 0.03880419948607533, null, 0.05232302002510064, 0.06651967129417816, null, 0.05232302002510064, 0.061854131080771174, null, 0.5255372899144904, 1.0, null, 0.9856657321753743, 0.9735566781039892, null, 0.9856657321753743, 0.9726157792860441, null, 0.5255372899144904, 0.6097877249110953, null, 0.6048797341992785, 0.5940986221121778, null, 0.6048797341992785, 0.6070465121611587, null, 0.494155887745048, 1.0, null, 0.9858295688675902, 0.9722559777233959, null, 0.9858295688675902, 0.974531713499242, null, 0.494155887745048, 0.8294390540401315, null, 0.8160493132653756, 0.8067967418855931, null, 0.8160493132653756, 0.8018006786208414, null, 0.494155887745048, 0.6585984395947108, null, 0.6483964260964881, 0.6442936502208256, null, 0.6483964260964881, 0.6345929836877295, null, 0.494155887745048, 0.0, null, 0.014299278882534685, 0.026176065933903474, null, 0.014299278882534685, 0.02752008742100528, null, 0.494155887745048, 0.044327127648275885, null, 0.058377860022878925, 0.06926937773176257, null, 0.058377860022878925, 0.07214769774147554, null, 0.2622846704229083, 0.3934180915241442, null, 0.38560665712169523, 0.37297016245233217, null, 0.38560665712169523, 0.38453279456117884, null, 0.2622846704229083, 0.13746874266267717, null, 0.14387570645069822, 0.15566385837597246, null, 0.14387570645069822, 0.1433328339154847, null, 0.2622846704229083, ...

# %%
for n in g1.nodes:
    g1.nodes[n]['indegree'] = 0

for n in g1.nodes:
    ind = 0
    for p in g1.predecessors(n):
        ind+=1
    g1.nodes[n]['indegree'] = ind
    print(g1.nodes[n]['label'] + ": " + str(g1.nodes[n]['indegree']))
# Out:
# Rachel: 5
# Jean: 1
# Bruna: 1
# Leo: 2
# Joao: 0
# Rapha: 3
# Carlos: 1
# Fred: 7
# Toyama: 7
# Vitoria: 5
# Hugo: 12
# Gabs: 2
# Elisa: 2
# Paulo: 0
# Sabrina: 2
# Forba: 7
# Rios: 2
# Ale: 0
# Graicer: 10
# Antonio: 3
# Martim: 2
# Pedro: 0
# Isa: 3
# Chen: 6
# Tirta: 0

# %%
for n in g2.nodes:
    g2.nodes[n]['indegree'] = 0
    g2.nodes[n]['outdegree_pond'] = 0
    g2.nodes[n]['indegree_pond'] = 0
    g2.nodes[n]['indegree_pond_norm'] = 0
    g2.nodes[n]['outdegree_pond_norm'] = 0
    
#indegree
for n in g2.nodes:
    
    count = 0
    for p in g2.predecessors(n):
        count+=1
    g2.nodes[n]['indegree'] = count

#outdegree ponderado
for n in g2.nodes:
    count = 0
    for p in g2.successors(n):
        count += g2.nodes[p]['indegree']    
    g2.nodes[n]['outdegree_pond'] = count
    
#indegree ponderado
total = 0
for n in g2.nodes:
    count = 0
    for p in g2.predecessors(n):
        count += g2.nodes[p]['outdegree_pond']    
    g2.nodes[n]['indegree_pond'] = count
    total += count
    
#indegree ponderado normalizado
totaln = 0
for n in g2.nodes:
    if g2.nodes[n]['indegree_pond'] != 0:
        g2.nodes[n]['indegree_pond_norm'] = g2.nodes[n]['indegree_pond']/total
        totaln += g2.nodes[n]['indegree_pond_norm']

#outdegree ponderado normalizado
for n in g2.nodes:
    count = 0
    for p in g2.successors(n):
        count += g2.nodes[p]['indegree_pond_norm']    
    g2.nodes[n]['outdegree_pond_norm'] = count

    if g2.nodes[n]['outdegree_pond'] != 0:
        #print(g2.nodes[n]['label'] + ": " + str(g2.nodes[n]['indegree']))
        #print(g2.nodes[n]['label'] + ": " + str(g2.nodes[n]['indegree_pond']))
        #print(g2.nodes[n]['label'] + ": " + str(g2.nodes[n]['indegree_pond_norm']))
        print(g2.nodes[n]['label'] + ": " + str(g2.nodes[n]['outdegree_pond']))
        print(g2.nodes[n]['label'] + ": " + str(g2.nodes[n]['outdegree_pond_norm']))
        print("\n")
# Out:
# Isa: 71
# Isa: 0.5015794669299112
#
#
# Chen: 61
# Chen: 0.4340572556762093
#
#
# Ale: 53
# Ale: 0.37739387956564663
#
#
# Rapha: 56
# Rapha: 0.3862783810463968
#
#
# Paulo: 29
# Paulo: 0.20829220138203358
#
#
# Elisa: 22
# Elisa: 0.1531095755182626
#
#
# Pedro: 57
# Pedro: 0.41332675222112536
#
#
# Antonio: 36
# Antonio: 0.2427443237907206
#
#
# Forba: 128
# Forba: 0.9329713721618953
#
#
# Hugo: 72
# Hugo: 0.5098716683119447
#
#
# Vitoria: 74
# Vitoria: 0.5296150049358341
#
#
# Fred: 60
# Fred: 0.43731490621915103
#
#
# Rachel: 78
# Rachel: 0.5393879565646594
#
#
# Toyama: 83
# Toyama: 0.5923988153998025
#
#
# Sabrina: 94
# Sabrina: 0.6768015794669299
#
#
# Gabs: 56
# Gabs: 0.3862783810463968
#
#
# Bruna: 43
# Bruna: 0.29842053307008887
#
#
# Martim: 60
# Martim: 0.4087857847976308
#
#
# Joao: 67
# Joao: 0.46584402764067134
#
#
# Jean: 95
# Jean: 0.6860809476801579
#
#
# Carlos: 30
# Carlos: 0.20365251727541955
#
#
# Leo: 7
# Leo: 0.050345508390918066
#
#
# Graicer: 65
# Graicer: 0.4670286278381047
